# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits

# %%
digits = load_digits()

# %%
dir(digits)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
digits.data[0]  # there are 1797 8x8 images out of which we have printed 1st image
# image is represented as 1-D array
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
plt.gray()
plt.matshow(digits.images[0])

# %%
# if you want to print first 5 images
plt.gray()
for i in range(5):
    plt.matshow(digits.images[0])

# %%
digits.target[0:5]
# Out:
# array([0, 1, 2, 3, 4])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(digits.data, digits.target, test_size = 0.2)

# %%
len(X_train)
# Out:
# 1437

# %%
len(X_test)
# Out:
# 360

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 6, 0, 2, 0, 0, 3, 7, 0, 8, 8, 9, 4, 2, 8, 1, 4, 0, 9, 5, 0, 4,
#        8, 4, 1, 5, 7, 4, 7, 1, 5, 5, 5, 5, 1, 7, 7, 8, 3, 3, 6, 6, 3, 4,
#        0, 0, 3, 4, 3, 5, 4, 5, 9, 1, 6, 1, 8, 4, 9, 9, 3, 5, 5, 1, 7, 9,
#        1, 6, 4, 4, 4, 8, 8, 5, 7, 8, 9, 9, 4, 2, 7, 8, 0, 5, 8, 8, 7, 2,
#        1, 0, 0, 6, 6, 4, 6, 4, 1, 8, 6, 1, 2, 6, 8, 0, 7, 1, 9, 6, 1, 8,
#        9, 6, 9, 2, 4, 4, 8, 0, 0, 9, 7, 3, 1, 1, 9, 3, 9, 6, 9, 5, 3, 9,
#        7, 2, 9, 3, 5, 8, 5, 2, 4, 9, 5, 2, 3, 7, 9, 4, 4, 4, 8, 4, 0, 7,
#        9, 9, 8, 2, 9, 4, 1, 4, 0, 4, 2, 1, 9, 5, 8, 6, 4, 0, 6, 6, 3, 6,
#        5, 3, 5, 7, 5, 5, 6, 0, 5, 5, 6, 9, 7, 1, 1, 5, 3, 4, 1, 4, 2, 7,
#        8, 2, 2, 6, 0, 8, 9, 4, 3, 0, 6, 6, 2, 1, 4, 2, 5, 8, 7, 0, 3, 7,
#        4, 9, 8, 6, 1, 9, 8, 4, 6, 7, 1, 8, 9, 7, 3, 9, 2, 5, 9, 2, 3, 9,
#        6, 1, 9, 5, 0, 1, 5, 7, 8, 1, 7, 0, 4, 9, 7, 5, 3, 4, 1, 7, 5, 3,
#        8, 8, 5, 7, 0, 4, 4, 2, 9, 6, 6, 7, 7, 4, 0, 3, 9, 2, 0, 4, 7, 0,
#        0, 7, 6, 5, 2, 7, 7, 9, 8, 0, 4, 6, 4, 9, 4, 7, 6, 1, 9, 6, 5, 6,
#        6, 3, 8, 9, 0, 0, 0, 6, 8, 1, 4, 6, 5, 2, 3, 8, 0, 1, 8, 2, 7, 9,
#        7, 4, 8, 2, 5, 2, 1, 5, 7, 5, 5, 7, 7, 7, 1, 0, 2, 6, 8, 4, 3, 1,
#        1, 1, 7, 5, 1, 0, 0, 2])

# %%
model.score(X_test, y_test)
# Out:
# 0.9611111111111111

# %%
plt.matshow(digits.images[67])

# %%
digits.target[67]
# Out:
# 6

# %%
model.predict([digits.data[67]])
# Out:
# array([6])
